# %% [markdown]
# <a href="https://colab.research.google.com/github/zaki-m-khan/swytchstation2B/blob/main/notebooks/swytchstation2BJobDescription.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import statements
import os
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#reading in the data
file_path = "data/job_title_des.csv"
df = pd.read_csv(file_path)

# %%
#look at data
df.head(15)
# Out:
#     Unnamed: 0               Job Title  \
# 0            0       Flutter Developer
# 1            1        Django Developer
# 2            2        Machine Learning
# 3            3           iOS Developer
# 4            4    Full Stack Developer
# 5            5          Java Developer
# 6            6    Full Stack Developer
# 7            7    JavaScript Developer
# 8            8         DevOps Engineer
# 9            9       Software Engineer
# 10          10  Database Administrator
# 11          11        Machine Learning
# 12          12        Machine Learning
# 13          13       Software Engineer
# 14          14       Software Engineer
#
#                                       Job Description
# 0   We are looking for hire experts flutter develo...
# 1   PYTHON/DJANGO (Developer/Lead) - Job Code(PDJ ...
# 2   Data Scientist (Contractor)\n\nBangalore, IN\n...
# 3   JOB DESCRIPTION:\n\nStrong framework outside o...
# 4   job responsibility full stack engineer – react...
# 5   Software Developer - Integration*\nImmediate O...
# 6   senior full stack developer \- 1800026h cwt lo...
# 7   Job Description:\n\nReactJS + NodeJs, Azure Fu...
# 8   Main Responsibilities and Deliverables:\nManag...
# 9   Overview\n\n\nBased in Silicon Valley, Tintri ...
# 10  richardsontexasunited state bausp4 boeing comp...
# 11  Remote, Any where\n2 - 4 years\n₹8L - ₹12L / y...
# 12  Excited by Big Data, Machine Learning and Pred...
# 13  As a member of our Software Engineering Group ...
# 14  JOB DESCRIPTION\n\nJob Title: Software Enginee...

# %%
print ("Displaying the distinct categories of resume and the number of records belonging to each category:\n\n")
print (df['Job Title'].value_counts())
# Out:
# Displaying the distinct categories of resume and the number of records belonging to each category:
#
#
# Job Title
# JavaScript Developer      166
# Java Developer            161
# Software Engineer         160
# Node js developer         160
# iOS Developer             159
# PHP Developer             156
# Flutter Developer         155
# DevOps Engineer           155
# Django Developer          152
# Machine Learning          152
# Backend Developer         147
# Network Administrator     145
# Database Administrator    139
# Full Stack Developer      138
# Wordpress Developer       132
# Name: count, dtype: int64

# %%
# cleaning the data
df['Job Description'] = df['Job Description'].str.replace(r'[^\x00-\x7F]+', ' ', regex=True)  # remove non-ASCII
df['Job Description'] = df['Job Description'].str.replace(r'\\r\\n', ' ', regex=True)         # remove literal '\r\n'
df['Job Description'] = df['Job Description'].str.replace(r'\s+', ' ', regex=True).str.strip() # clean up whitespace

print(df['Job Description'].head())
# Out:
# 0    We are looking for hire experts flutter develo...
# 1    PYTHON/DJANGO (Developer/Lead) - Job Code(PDJ ...
# 2    Data Scientist (Contractor) Bangalore, IN Resp...
# 3    JOB DESCRIPTION: Strong framework outside of i...
# 4    job responsibility full stack engineer react r...
# Name: Job Description, dtype: object

# %%
skills_list = [
    "machine learning", "deep learning", "data visualization", "data analysis",
    "data engineering", "data mining", "feature engineering",
    "statistical modeling", "predictive modeling", "object oriented programming",
    "software engineering", "web development", "backend development",
    "frontend development", "cloud computing", "devops", "nlp", "computer vision",
    "project management", "time management", "problem solving",
    "communication", "collaboration", "leadership", "teamwork",
    "critical thinking", "troubleshooting", "research", "testing",
     # programming languages
    "python", "java", "c", "c++", "c#", "r", "scala", "typescript", "javascript",
    # data science / ml tools
    "pandas", "numpy", "matplotlib", "tensorflow", "pytorch", "keras", "xgboost",
    "scikit-learn", "spss", "sas", "stata", "tableau", "power bi", "looker",
    # databases
    "sql", "mysql", "postgresql", "mongodb", "sqlite", "snowflake", "bigquery", "redshift",
    # devops / cloud
    "aws", "azure", "gcp", "docker", "kubernetes", "jenkins", "terraform", "ansible",
    "git", "github", "gitlab", "bitbucket", "linux",
    # web frameworks
    "flask", "django", "express", "spring boot", "fastapi", "node.js", "react", "vue", "angular",
    # ai / visualization
    "opencv", "powerpoint", "excel", "figma", "canva", "jira", "asana", "notion",
]

import re

def extract_keywords(text, keywords):
    found = []
    for word in keywords:
        # case insensitive search
        if re.search(r'\b' + re.escape(word) + r'\b', text, flags=re.IGNORECASE):
            found.append(word)
    return ", ".join(found) if found else None

df['Skills'] = df['Job Description'].apply(lambda x: extract_keywords(str(x), skills_list))
df[['Job Description', 'Skills']].head(15)
# Out:
#                                       Job Description  \
# 0   We are looking for hire experts flutter develo...
# 1   PYTHON/DJANGO (Developer/Lead) - Job Code(PDJ ...
# 2   Data Scientist (Contractor) Bangalore, IN Resp...
# 3   JOB DESCRIPTION: Strong framework outside of i...
# 4   job responsibility full stack engineer react r...
# 5   Software Developer - Integration* Immediate Op...
# 6   senior full stack developer \- 1800026h cwt lo...
# 7   Job Description: ReactJS + NodeJs, Azure Funct...
# 8   Main Responsibilities and Deliverables: Manage...
# 9   Overview Based in Silicon Valley, Tintri is a ...
# 10  richardsontexasunited state bausp4 boeing comp...
# 11  Remote, Any where 2 - 4 years 8L - 12L / yr (E...
# 12  Excited by Big Data, Machine Learning and Pred...
# 13  As a member of our Software Engineering Group ...
# 14  JOB DESCRIPTION Job Title: Software Engineer I...
#
#                                                Skills
# 0                                                None
# 1   communication, testing, python, sql, linux, fl...
# 2   machine learning, deep learning, communication...
# 3                                                   c
# 4   web development, communication, testing, javas...
# 5                  problem solving, testing, c, mysql
# 6           java, javascript, mongodb, react, angular
# 7                    communication, javascript, azure
# 8     devops, troubleshooting, python, java, r, linux
# 9   time management, problem solving, communicatio...
# 10                                                sql
# 11  machine learning, deep learning, cloud computi...
# 12  machine learning, data mining, communication, ...
# 13  machine learning, software engineering, commun...
# 14                       java, javascript, aws, azure
